# %%
import pandas as pd

employees = pd.read_csv("Employees.csv")
projects = pd.read_csv("Projects.csv")
performance = pd.read_csv("Performance.csv")
attrition = pd.read_csv("Attrition.csv")
timesheets = pd.read_csv("Timesheets.csv")

# %%
employees.info()
employees.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   EmployeeID       1000 non-null   int64
#  1   EmployeeName     1000 non-null   object
#  2   Gender           1000 non-null   object
#  3   Age              1000 non-null   int64
#  4   Department       1000 non-null   object
#  5   JobRole          1000 non-null   object
#  6   Location         1000 non-null   object
#  7   ExperienceYears  1000 non-null   int64
#  8   JobLevel         1000 non-null   int64
#  9   Salary           1000 non-null   int64
#  10  EducationLevel   1000 non-null   object
#  11  EmploymentType   1000 non-null   object
#  12  JoiningDate      1000 non-null   object
#  13  ManagerID        1000 non-null   int64
#  14  EmployeeStatus   1000 non-null   object
# dtypes: int64(6), object(9)
# memory usage: 117.3+ KB
# ...

# %%
employees.isnull().sum()
# Out:
# EmployeeID         0
# EmployeeName       0
# Gender             0
# Age                0
# Department         0
# JobRole            0
# Location           0
# ExperienceYears    0
# JobLevel           0
# Salary             0
# EducationLevel     0
# EmploymentType     0
# JoiningDate        0
# ManagerID          0
# EmployeeStatus     0
# dtype: int64

# %%
employees.duplicated().sum()
# Out:
# np.int64(0)

# %%
employees.shape
projects.shape
performance.shape
attrition.shape
timesheets.shape
# Out:
# (30000, 7)

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   EmployeeID       1000 non-null   int64
#  1   EmployeeName     1000 non-null   object
#  2   Gender           1000 non-null   object
#  3   Age              1000 non-null   int64
#  4   Department       1000 non-null   object
#  5   JobRole          1000 non-null   object
#  6   Location         1000 non-null   object
#  7   ExperienceYears  1000 non-null   int64
#  8   JobLevel         1000 non-null   int64
#  9   Salary           1000 non-null   int64
#  10  EducationLevel   1000 non-null   object
#  11  EmploymentType   1000 non-null   object
#  12  JoiningDate      1000 non-null   object
#  13  ManagerID        1000 non-null   int64
#  14  EmployeeStatus   1000 non-null   object
# dtypes: int64(6), object(9)
# memory usage: 117.3+ KB

# %%
employees.head()
employees.describe()
# Out:
#         EmployeeID          Age  ExperienceYears     JobLevel        Salary  \
# count  1000.000000  1000.000000      1000.000000  1000.000000  1.000000e+03
# mean    500.500000    42.532000         9.770000     3.224000  1.455674e+06
# std     288.819436     8.196594         6.150685     1.379031  6.267732e+05
# min       1.000000    21.000000         0.000000     1.000000  3.504660e+05
# 25%     250.750000    37.000000         4.000000     2.000000  9.096390e+05
# 50%     500.500000    43.000000        10.000000     3.000000  1.447042e+06
# 75%     750.250000    49.000000        15.000000     4.000000  1.960719e+06
# max    1000.000000    55.000000        20.000000     5.000000  2.538994e+06
#
#          ManagerID
# count  1000.000000
# mean     48.874000
# std      28.311334
# min       1.000000
# 25%      24.000000
# 50%      49.000000
# 75%      73.000000
# max     100.000000

# %%
employees["Department"].value_counts()
# Out:
# Department
# Cloud            137
# Finance          134
# Cybersecurity    129
# Operations       125
# Sales            123
# HR               121
# Technology       117
# Data & AI        114
# Name: count, dtype: int64

# %%
employees["JobRole"].value_counts()
# Out:
# JobRole
# Account Manager             75
# Security Analyst            70
# Operations Executive        69
# DevOps Engineer             69
# HR Executive                69
# Cloud Engineer              68
# Sales Executive             63
# Sales Manager               60
# Finance Analyst             59
# Cybersecurity Engineer      59
# Operations Manager          56
# HR Manager                  52
# Senior Software Engineer    43
# Software Engineer           43
# Data Analyst                41
# Business Analyst            40
# Data Engineer               33
# Technical Lead              31
# Name: count, dtype: int64

# %%
employees["Gender"].value_counts()
# Out:
# Gender
# Female    517
# Male      483
# Name: count, dtype: int64

# %%
employees["Salary"].describe()
# Out:
# count    1.000000e+03
# mean     1.455674e+06
# std      6.267732e+05
# min      3.504660e+05
# 25%      9.096390e+05
# 50%      1.447042e+06
# 75%      1.960719e+06
# max      2.538994e+06
# Name: Salary, dtype: float64

# %%
import matplotlib.pyplot as plt

employees["Department"].value_counts().plot(kind="bar")

plt.title("Employee Count by Department")
plt.xlabel("Department")
plt.ylabel("Number of Employees")
plt.xticks(rotation=45)

plt.show()

# %%
employees["Salary"].hist(bins=20)

plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Frequency")

plt.show()

# %%
employees["Gender"].value_counts().plot(kind="pie", autopct="%1.1f%%")

plt.title("Gender Distribution")

plt.show()

# %%
employees["ExperienceYears"].hist(bins=15)

plt.title("Experience Distribution")
plt.xlabel("Years of Experience")
plt.ylabel("Employees")

plt.show()

# %%
projects["ProjectStatus"].value_counts().plot(kind="bar")

plt.title("Projects by Status")
plt.xlabel("Status")
plt.ylabel("Count")

plt.show()

# %%
performance["PerformanceCategory"].value_counts().plot(kind="bar")

plt.title("Performance Categories")
plt.xlabel("Category")
plt.ylabel("Employees")

plt.show()

# %%
attrition["Attrition"].value_counts().plot(kind="bar")

plt.title("Attrition Distribution")
plt.xlabel("Attrition")
plt.ylabel("Employees")

plt.show()

# %%
timesheets["AttendanceStatus"].value_counts().plot(kind="bar")

plt.title("Attendance Status")
plt.xlabel("Status")
plt.ylabel("Count")

plt.show()

# %%
timesheets["WorkingHours"].hist(bins=20)

plt.title("Working Hours Distribution")
plt.xlabel("Hours")
plt.ylabel("Frequency")

plt.show()

# %%
timesheets["OvertimeHours"].hist(bins=15)

plt.title("Overtime Hours Distribution")
plt.xlabel("Overtime Hours")
plt.ylabel("Frequency")

plt.show()

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:Jai@1234@localhost:5432/IT_Server_Analytics"
)

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

password = quote_plus("Jai@1234")

engine = create_engine(
    f"postgresql+psycopg2://postgres:{password}@localhost:5432/IT_Server_Analytics"
)

with engine.connect() as conn:
    print("Connected Successfully")
# Out:
# Connected Successfully

# %%
employees.to_sql(
    "employees",
    engine,
    if_exists="replace",
    index=False
)

print("Employees table loaded")
# Out:
# ---------------------------------------------------------------------------
# DependentObjectsStillExist                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# DependentObjectsStillExist: cannot drop table employees because other objects depend on it
# ...

# %%
import pandas as pd

pd.read_sql("SELECT COUNT(*) FROM employees", engine)
# Out:
#    count
# 0   1000

# %%
pd.read_sql("SELECT COUNT(*) FROM employees", engine)
# Out:
#    count
# 0   1000

# %%
pd.read_sql("SELECT COUNT(*) FROM projects", engine)
# Out:
#    count
# 0    100

# %%
pd.read_sql("SELECT COUNT(*) FROM performance", engine)
# Out:
#    count
# 0   1000

# %%
pd.read_sql("SELECT COUNT(*) FROM timesheets", engine)
# Out:
#    count
# 0  30000

# %%
pd.read_sql("SELECT COUNT(*) FROM attrition", engine)
# Out:
#    count
# 0   1000

# %%
import requests
import pandas as pd

api_key = "kY5YvVHq4zkA8qJ8kR95QbIuaCyx1Nyl"

url = f"https://calendarific.com/api/v2/holidays?api_key={api_key}&country=IN&year=2026"

response = requests.get(url)

data = response.json()

holidays = data['response']['holidays']

holiday_df = pd.DataFrame([
    {
        "HolidayName": h["name"],
        "Date": h["date"]["iso"]
    }
    for h in holidays
])

holiday_df.head()
# Out:
#               HolidayName        Date
# 0          New Year's Day  2026-01-01
# 1  Hazarat Ali's Birthday  2026-01-03
# 2                  Pongal  2026-01-14
# 3         Makar Sankranti  2026-01-14
# 4         Vasant Panchami  2026-01-23

# %%
holiday_df.to_sql(
    "holidays",
    engine,
    if_exists="replace",
    index=False
)
# Out:
# 71

# %%
holiday_df.columns
# Out:
# Index(['HolidayName', 'Date'], dtype='object')

# %%
employees.to_csv("employees_final.csv", index=False)
projects.to_csv("projects_final.csv", index=False)
performance.to_csv("performance_final.csv", index=False)
attrition.to_csv("attrition_final.csv", index=False)
timesheets.to_csv("timesheets_final.csv", index=False)
